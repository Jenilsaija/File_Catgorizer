# %%
import os

# %%
#reading the folders file
folderpath = r"D:\New folder"
os.chdir(folderpath)

# %%
os.getcwd()
# Out:
# 'D:\\New folder'

# %%
os.listdir() # check the files.
# Out:
# ['Aashiqui 2 - Mashup - 720p  Funmaza.com .wmv',
#  'Akh_Lad_Jaave_With_Lyrics___Loveyatri___Aayush_S___Warina_H__Badshah,Tanishk_Bag.3gp',
#  'chaand_ne_kaho_aac_9722.m4a',
#  'Cham Cham - Baaghi - MP4.mp4',
#  'fee letter.doc',
#  'fee patrak.xls',
#  'Grub2Win & Code.zip',
#  'Jenil0910-small.jpg',
#  'picasa38-setup.exe',
#  'Saija-0004.jpg',
#  'Saija019.jpg',
#  'Sarthik.jpg',
#  'vlc-2.2.0-win32.exe',
#  '[MP3DOWNLOAD.TO] Lut Gaye (Full Song) Emraan Hashmi, Yukti _ Jubin N, Tanishk B, Manoj M _ Bhushan K _ Radhika-Vinay-320k.mp3']

# %%
# get the extention
list_extention = []
for f1 in os.listdir():
    extention = f1.split(".")[-1]
    list_extention.append(extention)

# %%
print(list_extention)
# Out:
# ['wmv', '3gp', 'm4a', 'mp4', 'doc', 'xls', 'zip', 'jpg', 'exe', 'jpg', 'jpg', 'jpg', 'exe', 'mp3']

# %%
list_extention=set(list_extention)

# %%
print(list_extention)
# Out:
# {'mp3', 'wmv', 'xls', '3gp', 'jpg', 'mp4', 'doc', 'exe', 'zip', 'm4a'}

# %%
len(list_extention)
# Out:
# 10

# %%
import shutil

# %%
path=os.environ["UserProfile"]+"\\"+"Desktop"+"\\"+"File Managment"
#os.mkdir(path)
try:
    shutil.rmtree(path)
    os.mkdir(path)
except:
    os.mkdir(path)

# How we can trnsfer the

# %%
print(path)
# Out:
# C:\Users\Saija\Desktop\File Managment
